# %%
from bs4 import BeautifulSoup
import requests
 
def get_title(soup):
     
    try:
        title = soup.find("span", attrs={"id":'productTitle'})
 
        title_value = title.string
 
        title_string = title_value.strip()
 
       
    except AttributeError:
        title_string = ""   
 
    return title_string
def get_price(soup):
 
    try:
        price = soup.find("span", attrs={'id':'priceblock_ourprice'}).string.strip()
 
    except AttributeError:
 
        try:
            price = soup.find("span", attrs={'id':'priceblock_dealprice'}).string.strip()
 
        except:     
            price = ""  
 
    return price
 
def get_rating(soup):
 
    try:
        rating = soup.find("i", attrs={'class':'a-icon a-icon-star a-star-4-5'}).string.strip()
         
    except AttributeError:
         
        try:
            rating = soup.find("span", attrs={'class':'a-icon-alt'}).string.strip()
        except:
            rating = "" 
 
    return rating
 
def get_review_count(soup):
    try:
        review_count = soup.find("span", attrs={'id':'acrCustomerReviewText'}).string.strip()
         
    except AttributeError:
        review_count = ""   
 
    return review_count
 
def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
 
    except AttributeError:
        available = "Not Available"
 
    return available    
 
 
if __name__ == '__main__':
 
    HEADERS = ({'User-Agent':
                'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
                'Accept-Language': 'en-US'})
 
    URL = "https://www.amazon.com/s?k=sofa&ref=nb_sb_noss_2"
     
    webpage = requests.get(URL, headers=HEADERS)
 
    soup = BeautifulSoup(webpage.content, "lxml")
 
    links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
 
  
    links_list = []
 
    for link in links:
        links_list.append(link.get('href'))
 
 

    for link in links_list:
 
        new_webpage = requests.get("https://www.amazon.com" + link, headers=HEADERS)
 
        new_soup = BeautifulSoup(new_webpage.content, "lxml")
         
        print("Product Title =", get_title(new_soup))
        print("Product Rating =", get_rating(new_soup))
        print("Number of Product Reviews =", get_review_count(new_soup))
        print("Availability =", get_availability(new_soup))
        print()
        print()
# Out:
# Product Title = POLY & BARK Napa 72" Apartment Sofa in Full-Grain Pure-Aniline Italian Tanned Leather in Cognac Tan
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 550 ratings
# Availability = Only 6 left in stock - order soon.
#
#
# Product Title = Lifestyle Solutions Austin Sofas, 80.7" W x 31.1" D x 32.3" H, Dark Grey
# Product Price =
# Product Rating = 3.7 out of 5 stars
# Number of Product Reviews = 541 ratings
# Availability = In Stock.
#
#
# Product Title = Ohuhu Convertible Sectional Sofa Couch with Reversible Chaise, L-Shape Upgraded Large Sofas Couches with Removable Ottoman & Storage Bag, 5-seat Sofas Sectional for Apartment Living Room & Small Space
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 7 ratings
# Availability = Only 9 left in stock - order soon.
#
#
# Product Title = POLY & BARK Napa 72" Apartment Sofa in Full-Grain Pure-Aniline Italian Tanned Leather in Cognac Tan
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 550 ratings
# Availability = Only 6 left in stock - order soon.
#
#
# Product Title = HUIMO Accent Chair, Button Tufted Upholstered Arm Chair, Linen Fabric Sofa Chairs, Leisure Living Room Chair, Comfy Mid-Century Modern Accent Room Chair for Bedroom, Reading Single Sofa Chair (Blue)
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 424 ratings
# Availability = In Stock.
#
#
# Product Title = Giantex 5-Position Adjustable Convertible Flip Chair, Sleeper Dorm Game Bed Couch Lounger Sofa Chair Mattress Living Room Furniture, Black
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 467 ratings
# Availability = In Stock.
#
#
# Product Title = Nolany Reversible Sectional Sofa Couch for Small Apartment L Shape Sofa Couch 3-seat Sectional Corner Couch (Mahogany Brown)
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 805 ratings
# Availability = In stock.
#
#
# Product Title = HONBAY Convertible Sectional Sofa Couch, L-Shaped Couch with Modern Linen Fabric for Small Space Light Grey
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 6,668 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand – Stone & Beam Lauren Genuine Leather Down-Filled Oversized Loveseat Sofa, 74"W, Dark Brown
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 1,294 ratings
# Availability = Only 16 left in stock - order soon.
#
#
# Product Title = Andeworld Modern Tufted Loveaseat Settee Sofa Bench Upholstered Couch for Dining Living Room Hallway or Entryway (Steel Gray)
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 226 ratings
# Availability = In stock.
#
#
# Product Title = HONBAY Convertible Sectional Sofa U Shaped Couch with Reversible Chaise Modular Oversized Couch Sectional Sofa with Ottomans, Aqua Blue
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 812 ratings
# Availability = In stock.
#
#
# Product Title = Signature Design by Ashley Tulen Modern Manual Pull Tab Reclining Sofa, Dark Gray
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 129 ratings
# Availability = In Stock.
#
#
# Product Title = POLY & BARK Napa 72" Apartment Sofa in Full-Grain Pure-Aniline Italian Tanned Leather in Cognac Tan
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 550 ratings
# Availability = Only 6 left in stock - order soon.
#
#
# Product Title = Amazon Brand – Rivet Revolve Modern Upholstered Sofa with Reversible Sectional Chaise, 80"W, Grey Weave
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 1,587 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand – Rivet Alonzo Contemporary Leather Loveseat Sofa, 64"W, Grey
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 91 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand – Rivet Aiden Mid-Century Modern Tufted Loveseat Sofa (74") - Light Gray
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 1,071 ratings
# Availability = Only 2 left in stock - order soon.
#
#
# Product Title = Amazon Brand - Stone & Beam Westview Extra-Deep Down-Filled Leather Loveseat Sofa Couch, 75.6"W, Brown
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 234 ratings
# Availability = Only 12 left in stock - order soon.
#
#
# Product Title = Acanva Mid-Century Modern 3-Seat Living Room Couch, Genuine Leather Sofa, Glazed Ginger
# Product Price =
# Product Rating = 5.0 out of 5 stars
# Number of Product Reviews = 1 rating
# Availability = Only 4 left in stock (more on the way).
#
#
# Product Title = Christopher Knight Home Josephine Mid-Century Modern Petite Fabric Sofa, Blue / Natural
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 51 ratings
# Availability = Usually ships within 5 to 7 days.
#
#
# Product Title = JAMFLY Convertible Sectional Sofa Couch, 3-seat L-Shaped Wide Reversible Couch with Modern Linen Fabric, Small Space Sofa for Living Room,Apartment and Office (Dark Grey)
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 4 ratings
# Availability = In Stock.
#
#
# Product Title = Shintenchi Convertible Sectional Sofa Couch, Modern Linen Fabric L-Shaped Couch 3-Seat Sofa Sectional with Reversible Chaise for Small Living Room, Apartment and Small Space (Dark Grey)
# Product Price =
# Product Rating = 3.5 out of 5 stars
# Number of Product Reviews = 1,765 ratings
# Availability = In Stock.
#
#
# Product Title = HUIMO Loveseat Sofa Small Couch Modern Love Seat 2-seat Sofa Button Tufted Upholstered Fabric Love Seats Furniture for Small Space, Living Room, Bedroom, Office, Small Apartment (Beige)
# Product Price =
# Product Rating = 4.8 out of 5 stars
# Number of Product Reviews = 15 ratings
# Availability = In Stock.
#
#
# Product Title = Serta Rane Convertible Sofa Bed, 66.1" W x 33.1" D x 29.5" H, Java
# Product Price =
# Product Rating = 3.8 out of 5 stars
# Number of Product Reviews = 604 ratings
# Availability = In Stock.
#
#
# Product Title = Mr. Kate Winston Sofa Sectional, Light Gray Linen
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 158 ratings
# Availability = In Stock.
#
#
# Product Title = Serta Palisades Upholstered Sofas for Living Room Modern Design Couch, Straight Arms, Soft Fabric Upholstery, Tool-Free Assembly - 73" Sofa - Light Gray
# Product Price =
# Product Rating = 3.4 out of 5 stars
# Number of Product Reviews = 2,113 ratings
# Availability = Only 1 left in stock (more on the way).
#
#
# Product Title = Lifestyle Solutions Harrington Sofa in Grey, Dark Grey
# Product Price =
# Product Rating = 3.8 out of 5 stars
# Number of Product Reviews = 606 ratings
# Availability = Only 2 left in stock - order soon.
#
#
# Product Title = Novogratz Brittany Sofa Futon - Premium Upholstery and Wooden Legs - Dark Gray
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 7,342 ratings
# Availability = Usually ships within 3 to 5 weeks.
#
#
# Product Title = Amazon Brand – Rivet Revolve Modern Upholstered Sofa Couch, 80"W, Linen
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 1,587 ratings
# Availability = In Stock.
#
#
# Product Title = Signature Design by Ashley Jarreau Contemporary Sofa Chaise Sleeper Chofa, Gray
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 287 ratings
# Availability = In Stock.
#
#
# Product Title = Nolany Convertible Sectional Sofa Couch with Reversible Chaise, L Shaped Sofa Couch with Storage Ottoman for Small Apartment, Dark Grey
# Product Price =
# Product Rating = 3.8 out of 5 stars
# Number of Product Reviews = 310 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand – Rivet Revolve Modern Upholstered Sofa Couch, 80"W, Linen
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 1,587 ratings
# Availability = In Stock.
#
#
# Product Title = Christopher Knight Home 305141 Aidan Mid Century Modern Tufted Fabric Sofa, Blue
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 108 ratings
# Availability = In Stock.
#
#
# Product Title = HONBAY Reversible Sectional Couch U-Shaped Sofa with Modern Fabric Modular Sectional Sofa with Chaises, Grey
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 812 ratings
# Availability = In stock.
#
#
# Product Title = GDFStudio Christopher Knight Home 61 75 X 33 27 Karen Traditional Chesterfield Loveseat Sofa, Beige and Dark Brown, 61.75 x 33.75 x 27.75
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 244 ratings
# Availability = In Stock.
#
#
# Product Title = Signature Design by Ashley - Hettinger Faux Leather Sofa, Brown
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 9 ratings
# Availability = Available to ship in 1-2 days.
#
#
# Product Title = Signature Design by Ashley - Darcy Microfiber Sofa Chaise, Salsa Red
# Product Price =
# Product Rating = 3.6 out of 5 stars
# Number of Product Reviews = 202 ratings
# Availability = Only 2 left in stock - order soon.
#
#
# Product Title = Lilola Home Lucca Reversible Sectional Sofa Couch, Storage Chaise, Pull Out Sleeper, L-Shape Lounge, Steel Gray, Linen
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 1,096 ratings
# Availability = In stock.
#
#
# Product Title = Esright 84.2”Mid-Century Sofa Couch,Tufted Synthetic Suede Fabric Modern Couch with 2 Bolster Pillows, Sofas Couches for Living Room,Apartment,Dorm & Office,Saddle Brown
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 162 ratings
# Availability = In Stock.
#
#
# Product Title = GDFStudio Christopher Knight Home Kyle Traditional Chesterfield Loveseat Sofa, Gray and Dark Brown, 61.75 x 33.75 x 27.75
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 166 ratings
# Availability = In Stock.
#
#
# Product Title = OSP Home Furnishings Russell Reversible Sectional Sofa with 2 Pillows and Coffee Finished Legs, Taupe
# Product Price =
# Product Rating = 4.3 out of 5 stars
# Number of Product Reviews = 84 ratings
# Availability = Usually ships within 3 to 5 days.
#
#
# Product Title = Rimdoc Power Lift Recliner Chair, Fiber Fabric Cloth Lift Chair, Recliner for Elderly, 2 Side Pockets and Cup Holders, Load Capacity Up to 360 lbs Electric Sofa for Living Room and Bedroom (Brown)
# Product Price =
# Product Rating = Previous page of related Sponsored Products
# Number of Product Reviews =
# Availability = In Stock.
#
#
# Product Title = Electric Power Lift Recliner Chair with Massage and Heat for Elderly/Adult, Fabric Home Massage Sofa Chairs with Heat, Remote Control, 3 Positions, Cup Holders， Side Pockets and USB Ports
# Product Price =
# Product Rating = 3.5 out of 5 stars
# Number of Product Reviews = 2 ratings
# Availability = In Stock.
#
#
# Product Title = Casa Andrea Milano llc Modern Plush Tufted Linen Fabric Splitback Living Room Sleeper Futon, Small, Grey
# Product Price =
# Product Rating = 3.6 out of 5 stars
# Number of Product Reviews = 12 ratings
# Availability = In Stock.
#
#
# Product Title = Signature Design by Ashley Tulen Modern Manual Pull Tab Reclining Sofa, Dark Gray
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 129 ratings
# Availability = In Stock.
#
#
# Product Title = Esright 88.6” Convertible Sectional Sofa Couch with Ottoman, Modern Tufted Linen Fabric L-Shaped Couch with Reversible Chaise, Suitable for Office,Living Room and Hotel Lobby, Black
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 196 ratings
# Availability = In Stock.
#
#
# Product Title = Amazon Brand – Rivet Cove Mid-Century Modern Tufted Leather Loveseat Sofa, 56"W, Caramel
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 370 ratings
# Availability = Only 9 left in stock (more on the way).
#
#
# Product Title = Morden Fort Modern Contemporary Sofa Couch with Deep Button Tufting Dutch Velvet, Solid Wood Frame and Wood Legs-Light Blue
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 282 ratings
# Availability = Only 14 left in stock - order soon.
#
#
# Product Title = Signature Design by Ashley - Jarreau Mid-Century Upholstered Sofa Chaise Sleeper, Blue
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 185 ratings
# Availability = In Stock.
#
#
# Product Title = Signature Design by Ashley - Earhart Contemporary Reclining Sofa, Brown
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 8 ratings
# Availability = Not Available
#
#
# Product Title = Signature Design by Ashley - Macleary Modern Velvet Sofa, Moss
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 22 ratings
# Availability = Usually ships within 3 to 5 weeks.
#
#
# Product Title = ZINUS Benton Sofa Couch / Grid Tufted Cushions / Easy, Tool-Free Assembly, Dark Grey
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 1,152 ratings
# Availability = Not Available
#
#
# Product Title = Better Homes & Gardens Nola Sofa Bed (Camel Faux Leather)
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 79 ratings
# Availability = In stock.
#
#
# Product Title = Amazon Brand – Rivet Brooke Contemporary Mid-Century Modern Tufted Leather Sofa Couch, 82"W, Grey
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 194 ratings
# Availability = In Stock.
#
#
# Product Title = 108'' Linen L-Shaped Sectional Sofa with Removeable Ottoman and 3 Pillows
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 13 ratings
# Availability = In stock.
#
#
# Product Title = Esright Right Facing Sectional Sofa with Ottoman,Convertible Corner Couches with Armrest Storage, Sectional Couch for Living Room & Apartment, Right Chaise & Gray
# Product Price =
# Product Rating = 3.8 out of 5 stars
# Number of Product Reviews = 158 ratings
# Availability = In Stock.
#
#
# Product Title = Vongrasig Modular Chesterfield Sofa Couch, Modern Fabric Reversible U-Shape Convertible 5- Seat Sectional Chaise Sofa for Living Room, Apartment and Small Spaces(Dark Gray)
# Product Price =
# Product Rating = 4.0 out of 5 stars
# Number of Product Reviews = 2 ratings
# Availability = Only 13 left in stock - order soon.
#
#
# Product Title = Casa Andrea Milano llc Modern Plush Tufted Linen Fabric Splitback Living Room Sleeper Futon, Small, Grey
# Product Price =
# Product Rating = 3.6 out of 5 stars
# Number of Product Reviews = 12 ratings
# Availability = In Stock.
#
#
# Product Title = Modway Valour Performance Velvet Upholstered Tufted Sofa, Mint
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 59 ratings
# Availability = In stock.
#
#
# Product Title = Casa AndreaMilano Modern Large Velvet Fabric U-Shape Sectional Sofa, Double Extra Wide Chaise Lounge Couch, Onyx
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 815 ratings
# Availability = Not Available
#
#
# Product Title = Divano Roma Furniture Classic Large Living Room Bonded Leather Scroll Arm Chesterfield Sofa (White)
# Product Price =
# Product Rating = 3.5 out of 5 stars
# Number of Product Reviews = 403 ratings
# Availability = Usually ships within 1 to 3 weeks.
#
#
# Product Title = BOWERY HILL Steel Gray Linen Reversible/Sectional Sleeper Sofa with Storage for Small Space
# Product Price =
# Product Rating = 4.2 out of 5 stars
# Number of Product Reviews = 800 ratings
# Availability = In Stock.
#
#
# Product Title = Casa Andrea Milano llc Modern Large Velvet Fabric Sectional Sofa, L-Shape Couch with Extra Wide Chaise Lounge, Navy
# Product Price =
# Product Rating = 3.7 out of 5 stars
# Number of Product Reviews = 599 ratings
# Availability = Not Available
#
#
# Product Title = Christopher Knight Home Karen Traditional Chesterfield Loveseat Sofa, Navy Blue and Dark Brown, 61.75 x 33.75 x 27.75, 306027
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 449 ratings
# Availability = In Stock.
#
#
# Product Title = HONBAY Convertible Sectional Sofa Couch L Shape Couch with Reversible Chaise Modular Sectional Sofa for Apartment, Grey
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 223 ratings
# Availability = In stock.
#
#
# Product Title = Christopher Knight Home Monture Sofas, Charcoal + Dark Walnut
# Product Price =
# Product Rating = 4.5 out of 5 stars
# Number of Product Reviews = 2 ratings
# Availability = Only 4 left in stock - order soon.
#
#
# Product Title = HONBAY Reversible Sectional Sofa Couch L-Shape Sofa Couch 4-seat Sofas Sectional for Apartment Bluish Grey
# Product Price =
# Product Rating = 4.1 out of 5 stars
# Number of Product Reviews = 2,450 ratings
# Availability = In stock.
#
#
# Product Title = Acanva Luxury Mid-Century Velvet Tufted Low Back Sofa Set L-Shape 2-Piece Living Room Couch, 113" W Right Hand Facing Sectional, Grey
# Product Price =
# Product Rating = 4.4 out of 5 stars
# Number of Product Reviews = 84 ratings
# Availability = Only 11 left in stock - order soon.
#
#
# Product Title = Amazon Brand – Stone & Beam Bradbury Chesterfield Tufted Loveseat Sofa Couch, 78.7"W, Navy
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 706 ratings
# Availability = In Stock.
#
#
# Product Title = Chunky Knit Blanket Hand Made Merino Wool Throw Boho Bedroom Sofa Home Decor Giant Yarn(Ivory White 47"x60")
# Product Price =
# Product Rating = 3.9 out of 5 stars
# Number of Product Reviews = 273 ratings
# Availability = Only 8 left in stock - order soon.
#
#
# Product Title = Outdoor Patio Dark Brown Rattan 10 Piece Sectional Furniture Set PE Wicker Conversation Sofa with Light Grey Cushion
# Product Price =
# Product Rating = 4.6 out of 5 stars
# Number of Product Reviews = 108 ratings
# Availability = Usually ships within 6 to 10 days.
#
#
# Product Title = AVAWING Power Lift Massage Chair, Modern Electric Recliners for Elderly Up to 330 LBS with Heat & Vibration, Linen Sofa Lift Living Room Chairs with Side Pocket, USB Interface, Remote Control (Khaki)
# Product Price =
# Product Rating = Previous page
# Number of Product Reviews =
# Availability = Only 20 left in stock - order soon.
#
#
# Product Title = NTBAY Acrylic Knitted Throw Blanket, Lightweight and Soft Cozy Decorative Woven Blanket with Tassels for Travel, Couch, Bed, Sofa, 51 x 67 Inches, Orange and White Wave
# Product Price =
# Product Rating = 4.7 out of 5 stars
# Number of Product Reviews = 2,493 ratings
# Availability = In Stock.
#
#
# Product Title = Vonanda Modern Sofa Couch,Breathable Linen Fabric 74 inch 3-Seater Sofa with Durable Metal Legs and Comfort Armrest for Compact Living Room or Apartment, Light Brown
# Product Price =
# Product Rating = 3.9 out of 5 stars
# Number of Product Reviews = 28 ratings
# Availability = In stock.
