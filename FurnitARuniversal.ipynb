# %%
from bs4 import BeautifulSoup
import requests
import re

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_2) AppleWebKit/601.3.9 (KHTML, like Gecko) Version/9.0.2 Safari/601.3.9'}
url = 'https://www.flipkart.com/search?q=sofa&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

response=requests.get(url,headers=headers)

soup=BeautifulSoup(response.content,'lxml')

for item in soup.select('[data-id]'):
    try:
        print('----------------------------------------')
        print(item.select('a img')[0]['alt'])
        print(item.select('a')[0]['href'])
        print(item.select('[id*=productRating]')[0].get_text().strip())
        prices = item.find_all(text=re.compile('₹')) 
        print(prices[0])
        discounts = item.find_all(text=re.compile('off')) 
        print(discounts[0])
        # url1=('flipkart.com' + str(item.select('a')[0]['href']))
        # response1=requests.get(url1,headers=headers)
        # soup1=BeautifulSoup(response1.content,'lxml')
        # for item in soup1.select('[data-id]'):
        #   dimensions = item.find_all('\d+')
        #   print(dimensions[0])

    except Exception as e:
	    #raise e
	    b=0
# Out:
# ----------------------------------------
# Teal Basics by Chumbak Jasper Fabric 6 Seater  Sofa
# /teal-basics-chumbak-jasper-fabric-6-seater-sofa/p/itm147a31538833d?pid=SOFG6ZA7ZYRC3RYD&lid=LSTSOFG6ZA7ZYRC3RYDZWB4MB&marketplace=FLIPKART&q=sofa&store=wwe%2Fc3z&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_0VF5Cng8YNFI2sPzMwfJu9L%2BNuHlsaEMVK70%2Fazq30YgTPE6fKbvhhDFbUHvG0W3SfXqYibQfiA%2Bpr9rgyl2eg%3D%3D&ppt=None&ppn=None&ssid=daddfpgrbk0000001637559472297&qH=7a2cc8b443e7cf56
# ----------------------------------------
# Teal Basics by Chumbak Marion Fabric 3 Seater  Sofa
# /teal-basics-chumbak-marion-fabric-3-seater-sofa/p/itm1a1e454805646?pid=SOFG6Z5K88SKYY5N&lid=LSTSOFG6Z5K88SKYY5NOUXF65&marketplace=FLIPKART&q=sofa&store=wwe%2Fc3z&srno=s_1_2&otracker=search&otracker1=search&fm=organic&iid=en_0VF5Cng8YNFI2sPzMwfJu9L%2BNuHlsaEMVK70%2Fazq30aDJi68hkJwAcVY2MzRSQhwv%2Bv2C1oQ3D8Ix%2FinaPWx4w%3D%3D&ppt=None&ppn=None&ssid=daddfpgrbk0000001637559472297&qH=7a2cc8b443e7cf56
# ...
